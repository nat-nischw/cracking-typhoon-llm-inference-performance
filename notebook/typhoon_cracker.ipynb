# %%
# !pip install txtai
# !pip uninstall numpy -y
# !pip install numpy==1.26.4
# !pip install pybind11==2.12.0

# %%
import re
from txtai import Embeddings, LLM
from IPython.display import display, HTML
from pygments import highlight
from pygments.lexers import PythonLexer
from pygments.formatters import HtmlFormatter

# %%
# Function to highlight and display code in color
def display_code_color(code):
    formatter = HtmlFormatter(style='colorful')
    highlighted_code = highlight(code, PythonLexer(), formatter)
    style = f"<style>{formatter.get_style_defs()}</style>"
    display(HTML(f"{style}{highlighted_code}"))

# %% [markdown]
# # SYSTEM PROMPT

# %%
"""
Natapong Nitarach - Typhoon Team Modify From: https://gist.github.com/davidmezzetti/1fac6bd406857431f1cdc74545bdfba9
"""

SYSTEM_PROMPT = {
    "non_self_reflection":"""{SYSTEM}
    You are an AI assistant that uses a Chain of Thought (CoT) approach with reflection to answer queries.
    
    Follow these steps:
    1. Think through the problem step by step within the <thinking> tags.
    2. Reflect on your thinking to check for any errors or improvements within the <reflection> tags.
    3. Make any necessary adjustments based on your reflection.
    4. Provide your final, concise answer within the <output> tags.
    
    Important: The <thinking> sections are for your internal reasoning process only. 
    Do not include any part of the final answer in these sections. 
    The actual response to the query must be entirely contained within the <output> tags.
    
    ### Response Format:
    <thinking>
    [Your step-by-step reasoning goes here. This is your internal thought process, not the final answer.]
    
    <code>
    ```python
    (Optional: functions to solve the question.)
    ```
    </code>
    
    </thinking>
    
    <output>
    "answer": [Your final , concise answer (Thai, English) to the query. This is the only part that will be shown to the user.]
    </output>""",


    
    "self_reflection": """{SYSTEM}
    You are an AI assistant that uses a Chain of Thought (CoT) approach with reflection to answer queries. 
    
    Follow these steps:
    1. Think through the problem step by step within the <thinking> tags.
    2. Reflect on your thinking to check for any errors or improvements within the <reflection> tags.
    3. Reflect within <reflection> tags after key steps. Assign a quality score (0.0-1.0) within <reward> tags to guide adjustments:
        - 0.8+: Continue current approach.
        - 0.5-0.7: Make minor adjustments.
        - Below 0.5: Consider backtracking.
    4. Make any necessary adjustments based on your reflection.
    5. Provide your final, concise answer within the <output> tags.
    
    Important: The <thinking> and <reflection> sections are for your internal reasoning process only. 
    Do not include any part of the final answer in these sections. 
    The actual response to the query must be entirely contained within the <output> tags.
    
    ### Response Format:
    <thinking>
    [Your step-by-step reasoning goes here. This is your internal thought process, not the final answer.]
    
    <code>
    ```python
    (Optional: functions to solve the question.)
    ```
    </code>
    
    <reflection>
    [Your reflection on your reasoning, checking for errors or improvements]
    </reflection>
    [Self-reflection on reasoning quality.]
    <reward>
    [Score between 0.0 and 1.0]
    </reward>
    [Any adjustments to your thinking based on your reflection]
    
    </thinking>
    
    <output>
    "reward": [Your final reflection score],
    "answer": [Your final , concise answer (Thai, English) to the query. This is the only part that will be shown to the user.]
    </output>
    """
    
}

# %% [markdown]
# # Functions

# %%
def cot(system, user, reflect):

    if reflect:
        system = SYSTEM_PROMPT['non_self_reflection'].format(SYSTEM=system)
    else:
        system = SYSTEM_PROMPT['self_reflection'].format(SYSTEM=system)

    # Run LLM inference
    response = llm([
            {"role": "system", "content": system},
            {"role": "user", "content": user}
        ],
        maxlength=4096
    )

    display_code_color(f'Logs of Thought:\n{response}')

    # Extract and return output
    match = re.search(r"<output>(.*?)(?:</output>|$)", response, re.DOTALL)
    return match.group(1).strip() if match else response

# %%
def rag(question, reflect=False):
    prompt = """
    Answer the following question using only the context below. Only include information
    specifically discussed.
    question: {question}
    context: {context};
    """

    # System prompt
    system = "You are a friendly assistant. You answer questions from users."

    # RAG context
    context = "\n".join([x["text"] for x in embeddings.search(question)])

    # Control Theory  with CoT with Self-Reflection + RAG
    return cot(system, prompt.format(question=question, context=context), reflect)

# %%
# Wikipedia Embeddings Index
embeddings = Embeddings()
embeddings.load(provider="huggingface-hub", container="neuml/txtai-wikipedia")

# LLM
llm = LLM("scb10x/llama-3-typhoon-v1.5x-8b-instruct")
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # Example:

# %% [markdown]
# ## Question-1
# A client requires £100,000 one year from now. If the stated annual rate is 2.50% compounded weekly, the deposit needed today is closest to:
# #### Options:
# - A: £97,500
# - B: £97,532 (✅)
# - C: £97,561

# %%
question = "Read the questions and answers carefully, and choose the one you think is appropriate among the three options A, B and C. Q:A client requires £100,000 one year from now. If the stated annual rate is 2.50% compounded weekly, the deposit needed today is closest to:,CHOICES: A: £97,500.,B: £97,532.,C: £97,561. Answer:"

# %% [markdown]
# ##### No reflection

# %%
result = rag(
    question,
    reflect=False
)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
# <span class="n">The</span> <span class="n">question</span> <span class="n">asks</span> <span class="k">for</span> <span class="n">the</span> <span class="n">deposit</span> <span class="n">needed</span> <span class="n">today</span> <span class="n">to</span> <span class="n">have</span> <span class="err">£</span><span class="mi">100</span><span class="p">,</span><span class="mi">000</span> <span class="n">one</span> <span class="n">year</span> <span class="kn">from</span> <span class="nn">now</span> <span class="k">with</span> <span class="n">a</span> <span class="n">stated</span> <span class="n">annual</span> <span class="n">rate</span> <span class="n">of</span> <span class="mf">2.50</span><span class="o">%</span> <span class="n">compounded</span> <span class="n">weekly</span><span class="o">.</span>
# <span class="n">We</span> <span class="n">need</span> <span class="n">to</span> <span class="n">find</span> <span class="n">the</span> <span class="n">closest</span> <span class="n">option</span> <span class="n">among</span> <span class="n">A</span><span class="p">,</span> <span class="n">B</span><span class="p">,</span> <span class="ow">and</span> <span class="n">C</span><span class="o">.</span>
# <span class="o">&lt;/</span><span class="n">thinking</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span>
# <span class="err">```</span><span class="n">python</span>
# <span class="c1"># Calculate the deposit needed today</span>
# <span class="n">deposit</span> <span class="o">=</span> <span class="mi">100000</span> <span class="o">/</span> <span class="p">(</span><span class="mi">1</span> <span class="o">+</span> <span class="mf">0.025</span><span class="o">/</span><span class="mi">52</span><span class="p">)</span> <span class="o">**</span> <span class="mi">52</span>
# <span class="err">```</span>
# <span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reflection</span><span class="o">&gt;</span>
# <span class="n">The</span> <span class="n">calculation</span> <span class="ow">is</span> <span class="n">based</span> <span class="n">on</span> <span class="n">the</span> <span class="n">formula</span> <span class="k">for</span> <span class="n">compound</span> <span class="n">interest</span><span class="p">,</span> <span class="n">where</span> <span class="n">the</span> <span class="n">deposit</span> <span class="ow">is</span> <span class="n">divided</span> <span class="n">by</span> <span class="n">the</span> <span class="n">future</span> <span class="n">value</span> <span class="n">factor</span><span class="o">.</span>
# <span class="o">&lt;/</span><span class="n">reflection</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reward</span><span class="o">&gt;</span>
# <span class="mf">0.9</span>
# <span class="o">&lt;/</span><span class="n">reward</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">output</span><span class="o">&gt;</span>
# <span class="s2">&quot;reward&quot;</span><span class="p">:</span> <span class="mf">0.9</span><span class="p">,</span>
# <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="s2">&quot;B: £97,532.&quot;</span>
# </pre></div>

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;reward&quot;</span><span class="p">:</span> <span class="mf">0.9</span><span class="p">,</span>
# <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="s2">&quot;B: £97,532.&quot;</span>
# </pre></div>

# %% [markdown]
# ##### Reflection

# %%
result = rag(
    question,
    reflect=True
)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
# <span class="n">Step</span> <span class="mi">1</span><span class="p">:</span> <span class="n">Understand</span> <span class="n">the</span> <span class="n">question</span>
# <span class="n">The</span> <span class="n">question</span> <span class="ow">is</span> <span class="n">asking</span> <span class="n">to</span> <span class="n">find</span> <span class="n">the</span> <span class="n">deposit</span> <span class="n">needed</span> <span class="n">today</span> <span class="k">for</span> <span class="n">a</span> <span class="n">client</span> <span class="n">who</span> <span class="n">requires</span> <span class="err">£</span><span class="mi">100</span><span class="p">,</span><span class="mi">000</span> <span class="n">one</span> <span class="n">year</span> <span class="kn">from</span> <span class="nn">now</span> <span class="k">with</span> <span class="n">a</span> <span class="n">stated</span> <span class="n">annual</span> <span class="n">rate</span> <span class="n">of</span> <span class="mf">2.50</span><span class="o">%</span> <span class="n">compounded</span> <span class="n">weekly</span><span class="o">.</span>
#
# <span class="n">Step</span> <span class="mi">2</span><span class="p">:</span> <span class="n">Calculate</span> <span class="n">the</span> <span class="n">deposit</span> <span class="n">needed</span>
# <span class="n">To</span> <span class="n">calculate</span> <span class="n">the</span> <span class="n">deposit</span> <span class="n">needed</span><span class="p">,</span> <span class="n">we</span> <span class="n">can</span> <span class="n">use</span> <span class="n">the</span> <span class="n">formula</span> <span class="k">for</span> <span class="n">compound</span> <span class="n">interest</span><span class="p">:</span>
#
# <span class="n">Deposit</span> <span class="n">needed</span> <span class="o">=</span> <span class="n">Future</span> <span class="n">value</span> <span class="o">/</span> <span class="p">(</span><span class="mi">1</span> <span class="o">+</span> <span class="p">(</span><span class="n">annual</span> <span class="n">rate</span> <span class="o">/</span> <span class="n">number</span> <span class="n">of</span> <span class="n">compounding</span> <span class="n">periods</span><span class="p">))</span><span class="o">^</span><span class="n">number</span> <span class="n">of</span> <span class="n">compounding</span> <span class="n">periods</span>
#
# <span class="n">Step</span> <span class="mi">3</span><span class="p">:</span> <span class="n">Plug</span> <span class="ow">in</span> <span class="n">the</span> <span class="n">values</span>
# <span class="n">Annual</span> <span class="n">rate</span> <span class="o">=</span> <span class="mf">2.50</span><span class="o">%</span>
# <span class="n">Number</span> <span class="n">of</span> <span class="n">compounding</span> <span class="n">periods</span> <span class="o">=</span> <span class="mi">52</span> <span class="p">(</span><span class="n">weekly</span> <span class="n">compounding</span><span class="p">)</span>
# <span class="n">Future</span> <span class="n">value</span> <span class="o">=</span> <span class="err">£</span><span class="mi">100</span><span class="p">,</span><span class="mi">000</span>
#
# <span class="n">Step</span> <span class="mi">4</span><span class="p">:</span> <span class="n">Calculate</span> <span class="n">the</sp

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="n">B</span><span class="o">.</span>
# </pre></div>

# %% [markdown]
# ## Question-2
# กำหนดให้ ABC เป็นรูปสามเหลี่ยมที่มีด้าน AB = AC   AD, BE และ CF เป็นเส้นมัธยฐานที่ลากจากจุด A, B และ C ไปยังด้าน BC, AC และ AB ตามลำดับ AD = 8 หน่วย ผลบวกของกำลังสองของความยาวเส้นมัธยฐานทั้งสามเส้นเท่ากับ 258 จงหาความยาวเส้นรอบรูปของสามเหลี่ยม ABC:
# ข้อใดต่อไปนี้ถูกต้อง
# 1.     27  หน่วย
# 2.     31  หน่วย
# 3.     32  หน่วย (✅)
# 4.     36  หน่วย

# %%
# ref: https://www.webythebrain.com/article/tu-60_math-test
question = """กำหนดให้ ABC เป็นรูปสามเหลี่ยมที่มีด้าน AB = AC   AD, BE และ CF เป็นเส้นมัธยฐานที่ลากจากจุด A, B และ C ไปยังด้าน BC, AC และ AB ตามลำดับ AD = 8 หน่วย ผลบวกของกำลังสองของความยาวเส้นมัธยฐานทั้งสามเส้นเท่ากับ 258 จงหาความยาวเส้นรอบรูปของสามเหลี่ยม ABC 
ข้อใดต่อไปนี้ถูกต้อง
1. 27  หน่วย
2. 31  หน่วย
3. 32  หน่วย
4. 36  หน่วย
"""

# %% [markdown]
# ##### No reflection

# %%
result = rag(
    question,
    reflect=False
)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
# <span class="mf">1.</span> <span class="n">เริ่มต้นด้วยการหาความยาวของเส้นมัธยฐาน</span> <span class="n">AD</span><span class="p">,</span> <span class="n">BE</span> <span class="n">และ</span> <span class="n">CF</span> <span class="n">จากข้อมูลที่ให้มา</span>
# <span class="mf">2.</span> <span class="n">จากนั้นใช้สูตร</span> <span class="n">Pythagorean</span> <span class="n">theorem</span> <span class="n">เพื่อหาความยาวของด้าน</span> <span class="n">BC</span><span class="p">,</span> <span class="n">AC</span> <span class="n">และ</span> <span class="n">AB</span>
# <span class="mf">3.</span> <span class="n">สุดท้ายใช้สูตรของความยาวเส้นรอบรูปของสามเหลี่ยม</span> <span class="p">(</span><span class="n">Perimeter</span> <span class="n">of</span> <span class="n">a</span> <span class="n">triangle</span><span class="p">)</span> <span class="n">เพื่อหาคำตอบ</span>
#
# <span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span>
# <span class="err">```</span><span class="n">python</span>
# <span class="c1"># Step 1: Calculate the length of the median AD, BE and CF</span>
# <span class="n">AD</span> <span class="o">=</span> <span class="mi">8</span>
#
# <span class="c1"># Step 2: Use Pythagorean theorem to calculate the length of sides BC, AC and AB</span>
# <span class="c1"># (Assuming the triangle is right-angled)</span>
#
# <span class="c1"># Step 3: Calculate the perimeter of the triangle</span>
# <span class="n">perimeter</span> <span class="o">=</span> <span class="n">BC</span> <span class="o">+</span> <span class="n">AC</span> <span class="o">+</span> <span class="n">AB</span>
# <span class="err">```</span>
# <span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reflection</span><span class="o">&gt;</span>
# <span class="mf">1.</span> <span class="n">การหาความยาวของเส้นมัธยฐาน</span> <span class="n">AD</span><span class="p">,</span> <span class="n">BE</span> <span class="n">และ</span> <span class="n">CF</span> <span class="n">จากข้อมูลที่ให้มาถูกต้อง</span>
# <span class="mf">2.</span> <span class="n">การใช้สูตร</span> <span class="n">Pythagorean</span> <span class="n">theorem</span> <span class="n">เพื่อหาความยาวของด้าน</span> <span class="n">BC</span><span class="p">,</span> <span class="n">AC</span> <span class="n">และ</span> <span class="n">AB</span> <span class="n">ถูกต้อง</span>
# <span class="mf">3.</span> <span class="n">การใช้สูตรของความยาวเส้นรอบรูปของสามเหลี่ยม</span> <span class="p">(</span><span class="n">Perimeter</span> <span class="n">of</span> <span class="n">a</span> <span class="n">triangle</span><span class="p">)</span> <span class="n">เพื่อหาคำตอบถูกต้อง</span>
# <span class="o">&lt;/</span><span class="n">reflection</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reward</span><span class="o">&gt;</span>
# <span class="mf">0.9</span>
# <span class="o">&lt;/</span><span class="n">reward</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">output</span><span class="o">&gt;</span>
# <span class="s2">&quot;reward&quot;</span><span class="p">:</span> <span class="mf">0.9</span><span class="p">,</span>
# <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="mi">31</span> <span class="n">หน่วย</span>
# <span class="o">&lt;/</span><span

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;reward&quot;</span><span class="p">:</span> <span class="mf">0.9</span><span class="p">,</span>
# <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="mi">31</span> <span class="n">หน่วย</span>
# </pre></div>

# %% [markdown]
# ##### Reflection

# %%
result = rag(
    question, 
    reflect=True
)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
# <span class="mf">1.</span> <span class="n">เริ่มต้นด้วยการหาความยาวของเส้นมัธยฐาน</span> <span class="n">AD</span><span class="p">,</span> <span class="n">BE</span> <span class="n">และ</span> <span class="n">CF</span> <span class="n">จากข้อมูลที่ให้มา</span>
# <span class="mf">2.</span> <span class="n">จากข้อมูลที่ให้มา</span> <span class="n">AD</span> <span class="o">=</span> <span class="mi">8</span> <span class="n">หน่วย</span>
# <span class="mf">3.</span> <span class="n">เราสามารถใช้สูตรของเส้นมัธยฐานเพื่อหาความยาวของ</span> <span class="n">BE</span> <span class="n">และ</span> <span class="n">CF</span> <span class="n">โดยใช้ความยาวของด้าน</span> <span class="n">AB</span> <span class="n">และ</span> <span class="n">AC</span>
# <span class="mf">4.</span> <span class="n">สูตรของเส้นมัธยฐานคือ</span><span class="p">:</span> <span class="n">เส้นมัธยฐาน</span> <span class="o">=</span> <span class="p">(</span><span class="n">ด้านที่ไม่มีเส้นมัธยฐาน</span> <span class="o">/</span> <span class="mi">2</span><span class="p">)</span>
# <span class="mf">5.</span> <span class="n">จากข้อมูลที่ให้มา</span> <span class="n">AB</span> <span class="o">=</span> <span class="n">AC</span> <span class="n">และ</span> <span class="n">AD</span> <span class="o">=</span> <span class="mi">8</span> <span class="n">หน่วย</span>
# <span class="mf">6.</span> <span class="n">ดังนั้น</span> <span class="n">BE</span> <span class="o">=</span> <span class="p">(</span><span class="n">AB</span> <span class="o">/</span> <span class="mi">2</span><span class="p">)</span> <span class="o">=</span> <span class="p">(</span><span class="n">AC</span> <span class="o">/</span> <span class="mi">2</span><span class="p">)</span> <span class="o">=</span> <span class="mi">8</span> <span class="n">หน่วย</span> <span class="n">และ</span> <span class="n">CF</span> <span class="o">=</span> <span class="p">(</span><span class="n">BC</span> <span class="o">/</span> <span class="mi">2</span><span class="p">)</span> <span class="o">=</span> <span class="mi">8</span> <span class="n">หน่วย</span>
# <span class="mf">7.</span> <span class="n">ผลบวกของกำลังสองของความยาวเส้นมัธยฐานทั้งสามเส้นเท่ากับ</span> <span class="mi">258</span>
# <span class="mf">8.</span> <span class="n">ดังนั้น</span> <span class="p">(</span><span class="n">AD</span><span class="o">^</span><span class="mi">2</span> <span class="o">+</span> <span class="n">BE</span><span class="o">^</span><span class="mi">2</span> <span class="o">+</span> <span class="n">CF</span><span class="o">^</span><span class="mi">2</span><span class="p">)</span> <span class="o">=</span> <span class="mi">258</span>
# <span class="mf">9.</span> <span class="n">โดยใช้ข้อมูลที่ได้จากข้อ</span> <span class="mi">6</span> <span class="n">เราสามารถแทนค่าในสมการได้</span>
# <span class="mf">10.</span> <span class="n">ดังนั้น</span> <span class="p">(</span><span class="mi">8</span><span class="o">^</span><span class="mi">2</span> <span class="o">+</span> <span class="mi">8</span><span class="o">^</span><span class="mi">2</span> <span class="o">+</span> <span class="mi">8</span><span class="o">^</span><span class="mi">2</span><span class="p">)</span> <span class="o">=</span> <span class="mi">258</span>
# <span class="mf">11.</span> <span class="n">ผลลัพธ์ของสมการคือ</span> <span class="mi">256</span> <span class="o">=</s

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="mf">3.</span> <span class="mi">32</span> <span class="n">หน่วย</span>
# </pre></div>

# %% [markdown]
# ## Question-3
# 1234*2039 เป็นเท่าไหร่? (2,516,126 ✅)

# %%
question = "1234*2039 เป็นเท่าไหร่?"

# %% [markdown]
# ##### No reflection

# %%
result = rag(
    question,
    reflect=False
    
)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
#     <span class="mf">1.</span> <span class="n">To</span> <span class="n">calculate</span> <span class="n">the</span> <span class="n">product</span> <span class="n">of</span> <span class="mi">1234</span> <span class="ow">and</span> <span class="mi">2039</span><span class="p">,</span> <span class="n">we</span> <span class="n">need</span> <span class="n">to</span> <span class="n">multiply</span> <span class="n">each</span> <span class="n">digit</span> <span class="n">of</span> <span class="mi">1234</span> <span class="n">by</span> <span class="mi">2039</span> <span class="ow">and</span> <span class="n">then</span> <span class="nb">sum</span> <span class="n">up</span> <span class="n">the</span> <span class="n">results</span><span class="o">.</span>
#     <span class="mf">2.</span> <span class="n">Multiply</span> <span class="mi">1</span> <span class="n">by</span> <span class="mi">2039</span><span class="p">:</span> <span class="mi">1</span> <span class="o">*</span> <span class="mi">2039</span> <span class="o">=</span> <span class="mi">2039</span>
#     <span class="mf">3.</span> <span class="n">Multiply</span> <span class="mi">2</span> <span class="n">by</span> <span class="mi">2039</span><span class="p">:</span> <span class="mi">2</span> <span class="o">*</span> <span class="mi">2039</span> <span class="o">=</span> <span class="mi">4078</span>
#     <span class="mf">4.</span> <span class="n">Multiply</span> <span class="mi">3</span> <span class="n">by</span> <span class="mi">2039</span><span class="p">:</span> <span class="mi">3</span> <span class="o">*</span> <span class="mi">2039</span> <span class="o">=</span> <span class="mi">6117</span>
#     <span class="mf">5.</span> <span class="n">Multiply</span> <span class="mi">4</span> <span class="n">by</span> <span class="mi">2039</span><span class="p">:</span> <span class="mi">4</span> <span class="o">*</span> <span class="mi">2039</span> <span class="o">=</span> <span class="mi">8156</span>
#     <span class="mf">6.</span> <span class="n">Sum</span> <span class="n">up</span> <span class="n">the</span> <span class="n">results</span><span class="p">:</span> <span class="mi">2039</span> <span class="o">+</span> <span class="mi">4078</span> <span class="o">+</span> <span class="mi">6117</span> <span class="o">+</span> <span class="mi">8156</span> <span class="o">=</span> <span class="mi">12390</span>
# <span class="o">&lt;/</span><span class="n">thinking</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reflection</span><span class="o">&gt;</span>
#     <span class="n">The</span> <span class="n">calculation</span> <span class="n">seems</span> <span class="n">correct</span><span class="p">,</span> <span class="ow">and</span> <span class="n">we</span> <span class="n">have</span> <span class="n">considered</span> <span class="n">each</span> <span class="n">digit</span> <span class="n">of</span> <span class="mf">1234.</span>
# <span class="o">&lt;/</span><span class="n">reflection</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">reward</span><span class="o">&gt;</span>
#     <span class="mf">1.0</span>
# <span class="o">&lt;/</span><span class="n">reward</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">output</span><span class="o">&gt;</span>
#     <span class="s2">&quo

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;reward&quot;</span><span class="p">:</span> <span class="mf">1.0</span><span class="p">,</span>
#     <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="s2">&quot;ผลลัพธ์ของการคูณ 1234 และ 2039 คือ 12390&quot;</span>
# </pre></div>

# %%
##### Reflection

# %%
result = rag(
    question,
    reflect=True
    
)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
#     <span class="n">To</span> <span class="n">calculate</span> <span class="n">the</span> <span class="n">product</span> <span class="n">of</span> <span class="mi">1234</span> <span class="ow">and</span> <span class="mi">2039</span><span class="p">,</span> <span class="n">we</span> <span class="n">need</span> <span class="n">to</span> <span class="n">multiply</span> <span class="n">each</span> <span class="n">digit</span> <span class="n">of</span> <span class="mi">1234</span> <span class="n">by</span> <span class="mi">2039</span> <span class="ow">and</span> <span class="n">then</span> <span class="nb">sum</span> <span class="n">up</span> <span class="n">the</span> <span class="n">results</span><span class="o">.</span>
#
#     <span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span>
#     <span class="err">```</span><span class="n">python</span>
#     <span class="c1"># Python code to calculate the product</span>
#     <span class="n">product</span> <span class="o">=</span> <span class="mi">0</span>
#     <span class="k">for</span> <span class="n">digit</span> <span class="ow">in</span> <span class="s1">&#39;1234&#39;</span><span class="p">:</span>
#         <span class="n">product</span> <span class="o">+=</span> <span class="nb">int</span><span class="p">(</span><span class="n">digit</span><span class="p">)</span> <span class="o">*</span> <span class="mi">2039</span>
#     <span class="err">```</span>
#     <span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span>
#
#     <span class="o">&lt;/</span><span class="n">thinking</span><span class="o">&gt;</span>
#
#     <span class="o">&lt;</span><span class="n">output</span><span class="o">&gt;</span>
#     <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="n">ผลลัพธ์ของการคูณ</span> <span class="mi">1234</span> <span class="n">และ</span> <span class="mi">2039</span> <span class="n">คือ</span> <span class="mi">2</span><span class="p">,</span><span class="mi">500</span><span class="p">,</span><span class="mf">946.</span>
#     <span class="o">&lt;/</span><span class="n">output</span><span class="o">&gt;</span>
# </pre></div>

# %%
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="n">ผลลัพธ์ของการคูณ</span> <span class="mi">1234</span> <span class="n">และ</span> <span class="mi">2039</span> <span class="n">คือ</span> <span class="mi">2</span><span class="p">,</span><span class="mi">500</span><span class="p">,</span><span class="mf">946.</span>
# </pre></div>

# %% [markdown]
# ## Question-4
# ขอสูตรไก่ย่างหน่อย (ของแทร่!!! ของแท้)

# %%
question = "ขอสูตรไก่ย่างหน่อย (ของแทร่!!! ของแท้)"
result = rag(question, reflect=True)
display_code_color(result)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">Logs</span> <span class="n">of</span> <span class="n">Thought</span><span class="p">:</span>
# <span class="o">&lt;</span><span class="n">thinking</span><span class="o">&gt;</span>
#     <span class="n">The</span> <span class="n">question</span> <span class="n">asks</span> <span class="k">for</span> <span class="n">a</span> <span class="n">recipe</span> <span class="k">for</span> <span class="n">grilled</span> <span class="n">chicken</span> <span class="p">(</span><span class="n">ไก่ย่าง</span><span class="p">)</span> <span class="ow">and</span> <span class="n">specifically</span> <span class="n">mentions</span> <span class="n">that</span> <span class="n">it</span> <span class="n">should</span> <span class="n">be</span> <span class="n">the</span> <span class="s2">&quot;real&quot;</span> <span class="ow">or</span> <span class="s2">&quot;authentic&quot;</span> <span class="n">recipe</span><span class="o">.</span>
#
#     <span class="n">The</span> <span class="n">context</span> <span class="n">provided</span> <span class="ow">is</span> <span class="n">a</span> <span class="n">combination</span> <span class="n">of</span> <span class="n">symbols</span> <span class="ow">and</span> <span class="n">characters</span> <span class="n">that</span> <span class="n">do</span> <span class="ow">not</span> <span class="n">seem</span> <span class="n">to</span> <span class="n">be</span> <span class="n">related</span> <span class="n">to</span> <span class="n">the</span> <span class="n">question</span> <span class="ow">or</span> <span class="n">the</span> <span class="n">context</span> <span class="n">of</span> <span class="n">a</span> <span class="n">recipe</span><span class="o">.</span>
#
#     <span class="n">To</span> <span class="n">answer</span> <span class="n">the</span> <span class="n">question</span><span class="p">,</span> <span class="n">we</span> <span class="n">need</span> <span class="n">to</span> <span class="n">find</span> <span class="n">a</span> <span class="n">recipe</span> <span class="k">for</span> <span class="n">grilled</span> <span class="n">chicken</span> <span class="n">that</span> <span class="ow">is</span> <span class="n">considered</span> <span class="n">authentic</span> <span class="ow">or</span> <span class="n">real</span><span class="o">.</span>
#
#     <span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span>
#     <span class="err">```</span><span class="n">python</span>
#     <span class="c1"># No code needed for this question</span>
#     <span class="err">```</span>
#     <span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span>
#
# <span class="o">&lt;/</span><span class="n">thinking</span><span class="o">&gt;</span>
#
# <span class="o">&lt;</span><span class="n">output</span><span class="o">&gt;</span>
# <span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="s2">&quot;สูตรไก่ย่างที่เป็นของแท้คือ การใช้เนื้อไก่ที่สดใหม่ และปรุงด้วยเครื่องเทศที่เหมาะสม เช่น กระเทียม พริกไทย และเกลือ นอกจากนี้ ควรใช้เตาหรือกระทะที่ร้อนพอสมควร เพื่อให้เนื้อไก่สุกและหอม&quot;</span>
# <span class="o">&lt;/</span><span class="n">output</span><span class="o">&gt;</span>
# </pre></div>
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .hll { background-color: #ffffcc }
# .c { color: #888888 } /* Comment */
# .err { color: #FF0000; background-color: #FFAAAA } /* Error */
# .k { color: #008800; font-weight: bold } /* Keyword */
# .o { color: #333333 } /* Operator */
# .ch { color: #888888 } /* Comment.Hashbang */
# .cm { color: #888888 } /* Comment.Multiline */
# .cp { color: #557799 } /* Comment.Preproc */
# .cpf { color: #888888 } /* Comment.PreprocFile */
# .c1 { color: #888888 } /* Comment.Single */
# .cs { color: #cc0000; font-weight: bold } /* Comment.Special */
# .gd { color: #A00000 } /* Generic.Deleted */
# .ge { font-style: italic } /* Generic.Emph */
# .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .gr { color: #FF0000 } /* Generic.Error */
# .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .gi { color: #00A000 } /* Generic.Inserted */
# .go { color: #888888 } /* Generic.Output */
# .gp { color: #c65d09; font-weight: bold } /* Generic.Prompt */
# .gs { font-weight: bold } /* Generic.Strong */
# .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .gt { color: #0044DD } /* Generic.Traceback */
# .kc { color: #008800; font-weight: bold } /* Keyword.Constant */
# .kd { color: #008800; font-weight: bold } /* Keyword.Declaration */
# .kn { color: #008800; font-weight: bold } /* Keyword.Namespace */
# .kp { color: #003388; font-weight: bold } /* Keyword.Pseudo */
# .kr { color: #008800; font-weight: bold } /* Keyword.Reserved */
# .kt { color: #333399; font-weight: bold } /* Keyword.Type */
# .m { color: #6600EE; font-weight: bold } /* Literal.Number */
# .s { background-color: #fff0f0 } /* Literal.String */
# .na { color: #0000CC } /* Name.Attribute */
# .nb { color: #007020 } /* Name.Builtin */
# .nc { color: #BB0066; font-weight: bold } /* Name.Class */
# .no { color: #003366; font-weight: bold } /* Name.Constant */
# .nd { color: #555555; font-weight: bold } /* Name.Decorator */
# .ni { color: #880000; font-weight: bold } /* Name.Entity */
# .ne { color: #FF0000; font-weight: bold } /* Name.Exception */
# .nf { color: #0066BB; font-weight: bold } /* Name.Function */
# .nl { color: #997700; font-weight: bold } /* Name.Label */
# .nn { color: #0e84b5; font-weight: bold } /* Name.Namespace */
# .nt { color: #007700 } /* Name.Tag */
# .nv { color: #996633 } /* Name.Variable */
# .ow { color: #000000; font-weight: bold } /* Operator.Word */
# .w { color: #bbbbbb } /* Text.Whitespace */
# .mb { color: #6600EE; font-weight: bold } /* Literal.Number.Bin */
# .mf { color: #6600EE; font-weight: bold } /* Literal.Number.Float */
# .mh { color: #005588; font-weight: bold } /* Literal.Number.Hex */
# .mi { color: #0000DD; font-weight: bold } /* Literal.Number.Integer */
# .mo { color: #4400EE; font-weight: bold } /* Literal.Number.Oct */
# .sa { background-color: #fff0f0 } /* Literal.String.Affix */
# .sb { background-color: #fff0f0 } /* Literal.String.Backtick */
# .sc { color: #0044DD } /* Literal.String.Char */
# .dl { background-color: #fff0f0 } /* Literal.String.Delimiter */
# .sd { color: #DD4422 } /* Literal.String.Doc */
# .s2 { background-color: #fff0f0 } /* Literal.String.Double */
# .se { color: #666666; font-weight: bold; background-color: #fff0f0 } /* Literal.String.Escape */
# .sh { background-color: #fff0f0 } /* Literal.String.Heredoc */
# .si { background-color: #eeeeee } /* Literal.String.Interpol */
# .sx { color: #DD2200; background-color: #fff0f0 } /* Literal.String.Other */
# .sr { color: #000000; background-color: #fff0ff } /* Literal.String.Regex */
# .s1 { background-color: #fff0f0 } /* Literal.String.Single */
# .ss { color: #AA6600 } /* Literal.String.Symbol */
# .bp { color: #007020 } /* Name.Builtin.Pseudo */
# .fm { color: #0066BB; font-weight: bold } /* Name.Function.Magic */
# .vc { color: #336699 } /* Name.Variable.Class */
# .vg { color: #dd7700; font-weight: bold } /* Name.Variable.Global */
# .vi { color: #3333BB } /* Name.Variable.Instance */
# .vm { color: #996633 } /* Name.Variable.Magic */
# .il { color: #0000DD; font-weight: bold } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="s2">&quot;answer&quot;</span><span class="p">:</span> <span class="s2">&quot;สูตรไก่ย่างที่เป็นของแท้คือ การใช้เนื้อไก่ที่สดใหม่ และปรุงด้วยเครื่องเทศที่เหมาะสม เช่น กระเทียม พริกไทย และเกลือ นอกจากนี้ ควรใช้เตาหรือกระทะที่ร้อนพอสมควร เพื่อให้เนื้อไก่สุกและหอม&quot;</span>
# </pre></div>
